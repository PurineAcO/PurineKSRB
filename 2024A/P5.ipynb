# %%
import P4 as sp
v_total=[]
for t in range(0,101):
    v_each=[]
    print("calc",t)
    sp1=sp.dragon(t-0.01)
    sp1.solvenb()
    sp2=sp.dragon(t+0.01)
    sp1.solvenb
    for i in range(224):
        v_each.append((sp2.road[i]-sp1.road[i])/0.02)
    v_max=max(v_each)
    for j in range(224):
        if v_each[j]==v_max:
            index=j
    v_total.append((j,v_max))
print(v_total)
